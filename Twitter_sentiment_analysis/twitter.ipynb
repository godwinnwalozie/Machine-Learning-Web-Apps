# %% [markdown]
# # Twitter sentiment analysis with TFIDF Vectorizer

# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from spacy.lang.en.examples import sentences 
from spacy.cli import download  # line 1
download("en_core_web_sm")
import spacy
import preprocess_kgptalkie as ps  # import the cleaning package
import re  # regex
from dython.model_utils import metric_graph
from dython.nominal import associations
from wordcloud import WordCloud
# from sklearn import set_config
# set_config(display="diagram")
# Out:
# Collecting en-core-web-sm==3.3.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.3.0/en_core_web_sm-3.3.0-py3-none-any.whl (12.8 MB)
# Requirement already satisfied: spacy<3.4.0,>=3.3.0.dev0 in /home/mazi/anaconda3/envs/ML/lib/python3.8/site-packages (from en-core-web-sm==3.3.0) (3.3.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/mazi/anaconda3/envs/ML/lib/python3.8/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.0.6)
# Requirement already satisfied: setuptools in /home/mazi/anaconda3/envs/ML/lib/python3.8/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (61.2.0)
# Requirement already satisfied: packaging>=20.0 in /home/mazi/anaconda3/envs/ML/lib/python3.8/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (21.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/mazi/anaconda3/envs/ML/lib/python3.8/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (4.64.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/mazi/anaconda3/envs/ML/lib/python3.8/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.28.0)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /home/mazi/anaconda3/envs/ML/lib/python3.8/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (0.7.7)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/mazi/anaconda3/envs/ML/lib/python3.8/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.0.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in /home/mazi/anaconda3/envs/ML/lib/python3.8/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/mazi/anaconda3/envs/ML/lib/python3.8/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.0.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /home/mazi/anaconda3/envs/ML/lib/python3.8/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (0.9.1)
# Requirement already satisfied: thinc<8.1.0,>=8.0.14 in /home/mazi/anaconda3/envs/ML/lib/python3.8/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (8.0.15)
# Requirement already satisfied: numpy>=1.15.0 in /home/mazi/anaconda3/envs/ML/lib/python3.8/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.21.5)
# Requirement already satisfied: jinja2 in /home/mazi/anaconda3/envs/ML/lib/python3.8/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.0.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/mazi/anaconda3/envs/ML/lib/python3.8/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.4.3)
# Requirement already satisfied: pathy>=0.3.5 in /home/mazi/anaconda3/envs/ML/lib/python3.8/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (0.6.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/mazi/anaconda3/envs/ML/lib/python3.8/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.0.7)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/mazi/anaconda3/envs/ML/lib/python3.8/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.3.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/mazi/anaconda3/envs/ML/lib/python3.8/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.0.1)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /home/mazi/anaconda3/envs/ML/lib/python3.8/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (0.4.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /home/mazi/anaconda3/envs/ML/lib/python3.8/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.8.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/mazi/anaconda3/envs/ML/lib/python3.8/site-packages (from packaging>=20.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.0.4)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /home/mazi/anaconda3/envs/ML/lib/python3.8/site-packages (from pathy>=0.3.5->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/mazi/anaconda3/envs/ML/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (4.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/mazi/anaconda3/envs/ML/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in /home/mazi/anaconda3/envs/ML/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/mazi/anaconda3/envs/ML/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/mazi/anaconda3/envs/ML/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/mazi/anaconda3/envs/ML/lib/python3.8/site-packages (from typer<0.5.0,>=0.3.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (8.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/mazi/anaconda3/envs/ML/lib/python3.8/site-packages (from jinja2->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.1.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# reading the csv file
df = pd.read_csv("airline_tweets.csv")
df.head(3)
# Out:
#              tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0  570306133677760513           neutral                        1.0000
# 1  570301130888122368          positive                        0.3486
# 2  570301083672813571           neutral                        0.6837
#
#   negativereason  negativereason_confidence         airline  \
# 0            NaN                        NaN  Virgin America
# 1            NaN                        0.0  Virgin America
# 2            NaN                        NaN  Virgin America
#
#   airline_sentiment_gold        name negativereason_gold  retweet_count  \
# 0                    NaN     cairdin                 NaN              0
# 1                    NaN    jnardino                 NaN              0
# 2                    NaN  yvonnalynn                 NaN              0
#
#                                                 text tweet_coord  \
# 0                @VirginAmerica What @dhepburn said.         NaN
# 1  @VirginAmerica plus you've added commercials t...         NaN
# 2  @VirginAmerica I didn't today... Must mean I n...         NaN
#
#                tweet_created tweet_location               user_timezone
# 0  2015-02-24 11:35:52 -0800            NaN  Eastern Time (US & Canada)
# 1  2015-02-24 11:15:59 -0800            NaN  Pacific Time (US & Canada)
# 2  2015-02-24 11:15:48 -0800      Lets Play  Central Time (US & Canada)

# %%
df.shape
# Out:
# (14640, 15)

# %%
df = df.loc[:,["airline","text","airline_sentiment"]] # rassigning df
df.head()
# Out:
#           airline                                               text  \
# 0  Virgin America                @VirginAmerica What @dhepburn said.
# 1  Virgin America  @VirginAmerica plus you've added commercials t...
# 2  Virgin America  @VirginAmerica I didn't today... Must mean I n...
# 3  Virgin America  @VirginAmerica it's really aggressive to blast...
# 4  Virgin America  @VirginAmerica and it's a really big bad thing...
#
#   airline_sentiment
# 0           neutral
# 1          positive
# 2           neutral
# 3          negative
# 4          negative

# %%
df["sentiment_encoded"] = df.airline_sentiment.apply(lambda x: (-1) if x == "negative" else (0) if x == "neutral" else (1) )

# %%
df[df.duplicated().values]
# Out:
#               airline                                               text  \
# 331    Virgin America                             @VirginAmerica Thanks!
# 515            United                                     @united thanks
# 1477           United                                 @united thank you!
# 1864           United                                  @united thank you
# 1938           United                                  @united thank you
# ...               ...                                                ...
# 13995        American  @AmericanAir  800 number will not even let you...
# 14386        American  @AmericanAir I want to speak to a human being!...
# 14392        American  @AmericanAir no response to DM or email yet.  ...
# 14543        American  @AmericanAir should reconsider #usairways acqu...
# 14556        American       @AmericanAir Thank you.....you do the same!!
#
#       airline_sentiment  sentiment_encoded
# 331            positive                  1
# 515            positive                  1
# 1477           positive                  1
# 1864           positive                  1
# 1938           positive                  1
# ...                 ...                ...
# 13995          negative                 -1
# 14386          negative                 -1
# 14392          negative                 -1
# 14543          negative                 -1
# 14556          positive                  1
#
# [188 rows x 4 columns]

# %%
df.drop_duplicates(keep ="first", inplace= True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.rename({"text" :"tweets"}, axis =1, inplace = True)

# %%
df.isna().sum()
# Out:
# airline              0
# tweets               0
# airline_sentiment    0
# sentiment_encoded    0
# dtype: int64

# %%
df.dropna(how = "any", inplace = True)

# %%
df.shape
df.head()
# Out:
#           airline                                             tweets  \
# 0  Virgin America                @VirginAmerica What @dhepburn said.
# 1  Virgin America  @VirginAmerica plus you've added commercials t...
# 2  Virgin America  @VirginAmerica I didn't today... Must mean I n...
# 3  Virgin America  @VirginAmerica it's really aggressive to blast...
# 4  Virgin America  @VirginAmerica and it's a really big bad thing...
#
#   airline_sentiment  sentiment_encoded
# 0           neutral                  0
# 1          positive                  1
# 2           neutral                  0
# 3          negative                 -1
# 4          negative                 -1

# %% [markdown]
# # Preprocessing and removing stopwords

# %%
def get_clean(x):
    x = str(x).lower().replace('\\', '').replace('_', ' ')
    x = ps.cont_exp(x)
    x = ps.remove_emails(x)
    x = ps.remove_urls(x)
    x = ps.remove_html_tags(x)
    x = ps.remove_rt(x)
    x = ps.remove_accented_chars(x)
    x = ps.remove_special_chars(x)
    x = re.sub("(.)\\1{2,}", "\\1", x)
    return x

# %%
df.tweets = df.tweets.apply(lambda x: get_clean(x))
# Out:
# /home/mazi/anaconda3/envs/ML/lib/python3.8/site-packages/bs4/__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(

# %%
# view sample cleaned text
df.isna().sum()
# Out:
# airline              0
# tweets               0
# airline_sentiment    0
# sentiment_encoded    0
# dtype: int64

# %%
df.to_csv("twitter_cleaned.csv", index = False)

# %%
X= df.tweets
y= df.sentiment_encoded

# %% [markdown]
# # Pipeline with needed libraries

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from sklearn.feature_extraction.text import TfidfVectorizer
from imblearn.pipeline import Pipeline as imbPipeline
from sklearn.neighbors import KNeighborsClassifier

# %%
model = Pipeline([('Vect',TfidfVectorizer(max_features = 100000, ngram_range =(1,2),stop_words = 'english')),
                   ('knn',KNeighborsClassifier(n_neighbors=100, leaf_size = 50))
                 
                  ])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %%
model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('Vect',
#                  TfidfVectorizer(max_features=100000, ngram_range=(1, 2),
#                                  stop_words='english')),
#                 ('knn', KNeighborsClassifier(leaf_size=50, n_neighbors=100))])

# %%
y_pred = model.predict(X_test )
y_pred
# Out:
# array([-1, -1, -1, ..., -1, -1, -1])

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.7200184501845018

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.73      0.95      0.83      2741
#            0       0.61      0.19      0.29       903
#            1       0.70      0.51      0.59       692
#
#     accuracy                           0.72      4336
#    macro avg       0.68      0.55      0.57      4336
# weighted avg       0.70      0.72      0.68      4336

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.73      0.95      0.83      2741
#            0       0.61      0.19      0.29       903
#            1       0.70      0.51      0.59       692
#
#     accuracy                           0.72      4336
#    macro avg       0.68      0.55      0.57      4336
# weighted avg       0.70      0.72      0.68      4336

# %%
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[2602,   62,   77],
#        [ 657,  169,   77],
#        [ 296,   45,  351]])

# %%
pd.DataFrame(cm)
# Out:
#       0    1    2
# 0  2602   62   77
# 1   657  169   77
# 2   296   45  351

# %%
fig, ax = plt.subplots(figsize = (20,8))
sns.heatmap(cm, annot = True, fmt = "d",)
# Out:
# <AxesSubplot:>

# %%
y_proba = model.predict_proba(X_test)
y_proba
# Out:
# array([[0.51, 0.26, 0.23],
#        [0.68, 0.17, 0.15],
#        [0.5 , 0.3 , 0.2 ],
#        ...,
#        [0.48, 0.33, 0.19],
#        [0.56, 0.33, 0.11],
#        [0.73, 0.09, 0.18]])

# %%
import pickle
pickle.dump(model, open("model_twitter.pkl", "wb"))

# %%
df
# Out:
#               airline                                             tweets  \
# 0      Virgin America                   virginamerica what dhepburn said
# 1      Virgin America  virginamerica plus youve added commercials to ...
# 2      Virgin America  virginamerica i did not today must mean i need...
# 3      Virgin America  virginamerica it is really aggressive to blast...
# 4      Virgin America  virginamerica and it is a really big bad thing...
# ...               ...                                                ...
# 14635        American  americanair thank you we got on a different fl...
# 14636        American  americanair leaving over 20 minutes late fligh...
# 14637        American  americanair please bring american airlines to ...
# 14638        American  americanair you have my money you change my fl...
# 14639        American  americanair we have 8 people so we need 2 know...
#
#       airline_sentiment  sentiment_encoded
# 0               neutral                  0
# 1              positive                  1
# 2               neutral                  0
# 3              negative                 -1
# 4              negative                 -1
# ...                 ...                ...
# 14635          positive                  1
# 14636          negative                 -1
# 14637           neutral                  0
# 14638          negative                 -1
# 14639           neutral                  0
#
# [14452 rows x 4 columns]

# %%
text = "".join(df['tweets'])
fig, ax = plt.subplots(figsize = (20,20))
wc = WordCloud(max_words = 500 , width = 1600 , height = 800,collocations=False).generate(text)
ax.imshow(wc)

# %%
super = df.loc[:,["tweets","airline_sentiment"]]
super[super.airline_sentiment == "negative"].tweets
# Out:
# 3        virginamerica it is really aggressive to blast...
# 4        virginamerica and it is a really big bad thing...
# 5        virginamerica seriously would pay 30 a flight ...
# 15              virginamerica sfopdx schedule is still mia
# 17       virginamerica i flew from new york city to sfo...
#                                ...
# 14631    americanair thank you for nothing on getting u...
# 14633    americanair my flight was cancelled flightled ...
# 14634             americanair right on cue with the delays
# 14636    americanair leaving over 20 minutes late fligh...
# 14638    americanair you have my money you change my fl...
# Name: tweets, Length: 9087, dtype: object

# %%
import scikitplot as skplt
fig, ax = plt.subplots(figsize=(14,7))
skplt.metrics.plot_roc(y_test, y_proba,ax= ax)
# Out:
# <AxesSubplot:title={'center':'ROC Curves'}, xlabel='False Positive Rate', ylabel='True Positive Rate'>

# %%
text = df['tweets'][:4]
text
# Out:
# 0                     virginamerica what dhepburn said
# 1    virginamerica plus youve added commercials to ...
# 2    virginamerica i did not today must mean i need...
# 3    virginamerica it is really aggressive to blast...
# Name: tweets, dtype: object
